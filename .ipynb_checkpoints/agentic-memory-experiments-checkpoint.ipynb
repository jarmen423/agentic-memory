# %% [markdown]
# # Agentic Memory — Healthcare Scale Experiments (Colab Runner)
#
# This notebook is the **ingest-and-experiment runner** for Plan B of the
# healthcare experiments (see `experiments/healthcare/synthea-experiments-scale.md`).
#
# It runs on Colab Pro with a GPU attached and does four things:
#
# 1. Mounts Google Drive so we can stream Synthea FHIR tarballs from
#    `G:/My Drive/.../big-healtcare-data/synthetic-data` without copying the
#    archive anywhere.
# 2. Bridges Colab to a remote Neo4j host over **Tailscale userspace
#    networking** so no public Bolt port is ever exposed.
# 3. Loads an **open-weights Nemotron embedding model on GPU** and streams
#    FHIR records through the existing `HealthcareIngestionPipeline`, which
#    writes memory nodes and entity edges to Neo4j and shadow-writes
#    temporal claims to SpacetimeDB Maincloud.
# 4. **Checkpoints every N patients to Drive** so a Colab session death
#    doesn't cost the whole run — the next session resumes from the last
#    committed patient ID.
#
# The notebook is tier-agnostic: the same cells run the 2K, 20K, and 200K
# tiers of the scale ladder. Tier selection is a single config value.
#
# ## Why a notebook, not a CLI script?
#
# Two things justify the notebook format:
#
# - **Colab is the cheapest GPU we can get for bulk embedding.** The
#   existing `scripts/ingest_synthea.py` runs CPU-side; a Colab notebook
#   is the path of least resistance to GPU-accelerated embedding without
#   reworking the CLI.
# - **Observability during long runs.** Colab cells let us watch batches
#   complete in real time, inspect intermediate state with a one-cell
#   query, and re-run just the parts that failed. That matters for
#   ingest runs that span hours and can die for Colab-specific reasons
#   (session timeout, runtime disconnect).
#
# The notebook does not duplicate ingestion logic — it orchestrates the
# same `HealthcareIngestionPipeline`, `EmbeddingService`, and
# `ConnectionManager` classes that `scripts/ingest_synthea.py` uses. This
# is deliberate: one ingest implementation, two runners.
#
# ## How this notebook fits the repo
#
# ```
# experiments/healthcare/
#   synthea-experiments.md          ← Plan A (original, small-scale plan)
#   synthea-experiments-scale.md    ← Plan B (scale-ladder plan; this notebook runs it)
#   collab/                         ← partner + credit-program drafts
#   tasks/                          ← (future) pre-generated QA tasks + tier patient lists
#   results/                        ← (future) per-tier metric JSON + scale-curve plot
#
# scripts/ingest_synthea.py         ← CPU-side ingest runner (production-style CLI)
# agentic-memory-experiments.ipynb  ← this notebook (Colab-side ingest runner)
# ```

# %% [markdown]
# ## Prerequisites
#
# Do these once, before the first run of this notebook.
#
# ### 1. Phase 0 code changes must be merged
#
# The notebook assumes the Phase 0 infrastructure items are in `main`:
#
# - [x] `src/agentic_memory/healthcare/fhir_loader.py` iterates tar members
#       lazily (no `getmembers()` on the outer archive).
# - [x] `src/agentic_memory/temporal/bridge.py` cleanly parses the Node
#       helper output (the `JSONDecodeError` we hit during preflight).
# - [x] `EmbeddingService` supports `provider="nemotron_local"` against a
#       local GPU backend (HuggingFace transformers, auto-dim).
# - [x] `ConnectionManager.setup_database(embedding_dim=...)` reconciles
#       existing vector indexes idempotently.
#
# ### 2. Neo4j host is provisioned and reachable
#
# The notebook expects a Neo4j instance reachable over Tailscale (see
# "Bridge mechanism" in Plan B). Before the first run:
#
# - Neo4j 5.x running on the host (we use Hetzner CPX52).
# - Tailscale installed on the Neo4j host, joined to the same tailnet
#   this notebook will join.
# - `bolt://` accessible on the host's Tailscale IP.
# - `healthcare_embeddings` vector index absent OR already at the same
#   dimension the embedding model produces (the notebook creates it if
#   missing and drop-and-recreates if the dim does not match).
# - SpacetimeDB Maincloud project live and the bindings module path
#   set in env.
#
# ### 3. Runtime environment: Colab web UI vs. Cursor / VSCode extension
#
# The notebook is written to work cleanly in both:
#
# **Colab web UI.** Everything "just works" — `drive.mount()`,
# `userdata.get()` for Secrets, native file browser, etc.
#
# **Cursor / VSCode Google Colab extension** (v0.2.1+, Feb 2026 or later).
# Current capabilities:
#
# - `google.colab.drive.mount()` **works** natively — you'll get the same
#   OAuth flow as in the web UI. The mount cell below just calls it.
# - **Upload to Colab** (right-click file/folder in VS Code Explorer →
#   *Upload to Colab*) uploads directly into `/content/...` on the Colab
#   runtime. This is the most convenient way to bring your local repo or
#   a local `.env` file onto the runtime.
# - **Colab Terminal** (experimental command) gives you a shell on the
#   Colab VM if you want to inspect paths or run `ls /content`.
# - **`google.colab.userdata.get()` is still unsupported** from the
#   extension ([issue #215](https://github.com/googlecolab/colab-vscode/issues/215)).
#   Do **not** rely on the Colab Secrets sidebar if you're running from
#   Cursor; use a dotenv file instead (see below).
#
# ### 4. Secrets available at runtime
#
# The notebook picks up secrets adaptively. You only need to provide them
# via **one** of these mechanisms:
#
# **A. Colab web UI — Secrets sidebar (web UI only).**
# Open Colab's **Secrets** sidebar (key icon) and add the keys below with
# "Notebook access" ON. This path is skipped if `userdata.get()` is
# unavailable (Cursor/VSCode extension).
#
# **B. Dotenv file on the Colab runtime (recommended for Cursor).**
# Either:
#   - Right-click `experiments/healthcare/.env` (or any `.env`) in the
#     VS Code Explorer → **Upload to Colab**, and place it at
#     `/content/agentic-memory/experiments/healthcare/.env`, OR
#   - Run the `%%writefile /content/secrets.env` cell below to create
#     one in place (safest for keys you don't want checked in).
#
# The notebook scans these paths, in order, and imports any keys it finds:
#   - `/content/secrets.env`
#   - `/content/.env`
#   - `/content/agentic-memory/experiments/healthcare/.env`
#
# Format — one `KEY=value` per line, comments allowed with `#`.
#
# **C. Set in a cell directly (any runtime).**
# If neither of the above is convenient, `os.environ["KEY"] = "..."`
# in a cell above the preflight section works too.
#
# ### Keys the notebook reads
#
# | Key | Value |
# |---|---|
# | `TAILSCALE_AUTH_KEY` (or `TAILSCALE_AUTHKEY`) | Pre-authorised Tailscale key, ephemeral, tagged `tag:colab` |
# | `NEO4J_URI` | `bolt://<tailscale-ip-or-hostname>:7687` |
# | `NEO4J_USER` (or `NEO4J_USERNAME`) | `neo4j` |
# | `NEO4J_PASSWORD` | (the experiment Neo4j password) |
# | `STDB_URI` | SpacetimeDB Maincloud URL |
# | `STDB_TOKEN` | SpacetimeDB auth token |
# | `STDB_BINDINGS_MODULE` | path to the compiled bindings module on the Colab filesystem after repo clone |
# | `NVIDIA_API_KEY` | (only if we fall back to API-hosted Nemotron; optional for the GPU path) |
#
# Each cell that reads a secret declares which ones it needs. Missing
# required secrets produce a clear error, not a silent default.
#
# ### 5. Drive layout
#
# The notebook expects the following paths under your mounted Drive:
#
# ```
# My Drive/
#   kubuntu/agentic-memory/
#     big-healtcare-data/
#       synthetic-data/
#         synthea_2017_02_27.tar.gz         (2K/20K tiers source)
#         synthea_1m_fhir_3_0_May_24.tar.gz (200K tier source subset)
#     experiments/
#       healthcare/
#         checkpoints/   (written by this notebook)
#         results/       (written by this notebook)
# ```
#
# Checkpoint files are written here, not into the repo, because Colab's
# ephemeral filesystem loses state on session death but Drive persists.

# %% [markdown]
# ## Section 1 — Runtime sanity
#
# Before we install anything heavy, confirm the Colab runtime is actually
# what we asked for (GPU attached, Python version reasonable, Drive
# mountable). Each of these failing has a different remediation, so we
# check them separately and fail fast.

# %%
# %%writefile /content/secrets.env
# # Experiment secrets for the Hetzner Neo4j VM + SpacetimeDB Maincloud.
# # Edit values in place or overwrite with a real .env uploaded from Cursor.
# TAILSCALE_AUTH_KEY=tskey-auth-kVR4R1EUju11CNTRL-SRdDMNXeXRHH2eoBF7dTRHnpi5fZfXd2
# NEO4J_URI=bolt://100.113.38.23:7687
# NEO4J_USER=neo4j
# NEO4J_PASSWORD=uSH68vQVJ6DUfkse3wWAR/cm9u8suo3hKRtwgnnzHpY=
# STDB_BINDINGS_MODULE=packages/am-temporal-kg/generated-bindings/index.ts
# STDB_URI=https://maincloud.spacetimedb.com
# STDB_MODULE_NAME=agentic-memory-temporal
# STDB_CONFIRMED_READS=true
# STDB_TOKEN=eyJhbGciOiJSUzI1NiJ9.eyJzdWIiOiIwMUtKOUJDSFI2RVdaU1hWSEJHRE1LQU1OTiIsImlzcyI6Imh0dHBzOi8vYXV0aC5zcGFjZXRpbWVkYi5jb20iLCJhdWQiOiJzcGFjZXRpbWVkYiIsImlhdCI6MTc3NjA4OTIwNSwiZXhwIjoxODM5MTYxMjA1fQ.L50MSkgpBuPFy-tBjTckEEdrCEZeEIbatfJlcYJPh7JpYH8sfmHWgJ7--Ixvqrz_5bQOa00yw8Q-uLSfceQu_TN7aAUmnyJ3NO4-cTPugduTON1a3N_jdBM3MkGqzf_ze2n2o_La1x1MD4wXPmAqBzhH8bT-HE16X7_BViBB5RfrO-IMxS1UG7AznbOC40NBZKik1v7YnmNfb8G07ql1QO82Jpo83swPt8zJLfHMoDNoZZwJDhc96teO_b6U81nsGgbgH3HcaZs1w8d5q6euew3KY3j5RmcSnvodUXXSrkEepR8qxHfWE_F1TPf2xfc9ELuUx_9RTA1HF5bqac17nw
# Out:
# Writing /content/secrets.env

# %%
"""Runtime sanity check.

Confirms the Colab VM has:
- A supported Python version for the project (>=3.10).
- A CUDA-capable GPU reachable from PyTorch.
- The expected Linux tools available (apt, curl) for later cells.

Failures here should stop the notebook. There is no point continuing
to install 5 GB of dependencies if the runtime is misconfigured.
"""
import platform
import shutil
import subprocess
import sys


def _assert_python_version(min_major: int = 3, min_minor: int = 10) -> None:
    """Fail fast if the Colab runtime is on a Python older than the project supports."""
    major, minor = sys.version_info.major, sys.version_info.minor
    if (major, minor) < (min_major, min_minor):
        raise RuntimeError(
            f"Python {major}.{minor} is too old — project requires "
            f">= {min_major}.{min_minor}. Switch the Colab runtime."
        )
    print(f"Python {platform.python_version()} OK")


def _assert_gpu_available() -> None:
    """Fail fast if no CUDA GPU is attached to this Colab runtime.

    We want a GPU because the embedding model (Nemotron) runs ~100x faster
    on GPU than CPU for our batch sizes. Without it, a 200K-patient tier
    becomes unworkably slow.
    """
    try:
        output = subprocess.check_output(
            ["nvidia-smi", "--query-gpu=name,memory.total", "--format=csv,noheader"],
            text=True,
            timeout=10,
        )
    except (FileNotFoundError, subprocess.SubprocessError) as exc:
        raise RuntimeError(
            "nvidia-smi not available — Colab runtime has no GPU. "
            "Runtime -> Change runtime type -> pick a GPU instance."
        ) from exc

    gpu_line = output.strip().splitlines()[0] if output.strip() else ""
    if not gpu_line:
        raise RuntimeError("GPU present but no device info returned; retry the runtime.")
    print(f"GPU: {gpu_line}")


def _assert_basic_tools() -> None:
    """Confirm the shell tools later cells assume are installed."""
    for tool in ("curl", "apt-get", "git"):
        if shutil.which(tool) is None:
            raise RuntimeError(f"Required tool '{tool}' is missing from PATH.")
    print("Shell tools: curl, apt-get, git OK")


_assert_python_version()
_assert_gpu_available()
_assert_basic_tools()
print("\nRuntime sanity: PASS")
# Out:
# Python 3.12.13 OK
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition, 97887 MiB
# Shell tools: curl, apt-get, git OK
#
# Runtime sanity: PASS

# %% [markdown]
# ## Section 2 — Mount Drive and clone the repo
#
# Two separate operations, one cell each, so a failure in one doesn't
# mask the other.
#
# Drive is mounted read-only-ish (we write to the `checkpoints/` and
# `results/` subdirectories, but never touch the source tarballs). The
# repo is cloned fresh into the Colab session so we pick up any recent
# commits; no pip-installing from Drive.

# %%
"""Mount Google Drive (single step, single source of truth).

After this cell runs, the Synthea tarballs should be reachable at:
    /content/drive/MyDrive/kubuntu/agentic-memory/big-healtcare-data/synthetic-data/

We do NOT copy the tarballs anywhere. The FHIR loader streams members
directly from the mounted Drive filesystem.

Runtime compatibility:
  - Colab web UI: native.
  - Cursor / VSCode Colab extension v0.2.1+: `drive.mount()` is now
    supported and triggers the same OAuth flow as the web UI.
  - Non-Colab kernel (rare here): the `google.colab` import fails and
    we fall back to a pre-staged local path at `/content/synthea`.

If you prefer not to mount Drive at all, put the tarball(s) at
`/content/synthea/` via **Upload to Colab** (right-click the local file
in VS Code Explorer) and the config cell will find them there.
"""
from pathlib import Path

DRIVE_MOUNT = Path("/content/drive")
DRIVE_READY = False

try:
    from google.colab import drive  # type: ignore[import-not-found]
except ImportError:
    print("google.colab not available; skipping Drive mount (non-Colab runtime).")
else:
    my_drive = DRIVE_MOUNT / "MyDrive"
    if my_drive.is_dir():
        print(f"Drive already mounted at {DRIVE_MOUNT}")
        DRIVE_READY = True
    else:
        # Triggers the OAuth flow in both Colab web UI and Cursor/VSCode
        # extension v0.2.1+. A browser tab or auth prompt will appear.
        drive.mount(str(DRIVE_MOUNT))  # type: ignore[attr-defined]
        DRIVE_READY = my_drive.is_dir()

if DRIVE_READY:
    SYNTHEA_DIR = DRIVE_MOUNT / "MyDrive/kubuntu/agentic-memory/big-healtcare-data/synthetic-data"
    EXPERIMENT_DIR = DRIVE_MOUNT / "MyDrive/kubuntu/agentic-memory/experiments/healthcare"
else:
    # No Drive — look for tarballs uploaded to the Colab runtime's local
    # disk instead. Everything else (checkpoints, results) stays local too.
    SYNTHEA_DIR = Path("/content/synthea")
    EXPERIMENT_DIR = Path("/content/experiments/healthcare")
    SYNTHEA_DIR.mkdir(parents=True, exist_ok=True)

CHECKPOINT_DIR = EXPERIMENT_DIR / "checkpoints"
RESULTS_DIR = EXPERIMENT_DIR / "results"
CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

for label, path in [
    ("Drive mount", DRIVE_MOUNT if DRIVE_READY else Path("/content (local)")),
    ("Synthea source", SYNTHEA_DIR),
    ("Experiment dir", EXPERIMENT_DIR),
    ("Checkpoints", CHECKPOINT_DIR),
    ("Results", RESULTS_DIR),
]:
    marker = "OK" if path.exists() else "MISSING"
    print(f"[{marker}] {label}: {path}")

if not DRIVE_READY:
    print(
        "\nDrive not mounted: upload (or rclone-copy) the Synthea tarball into "
        f"{SYNTHEA_DIR}/ before running the config cell. The tarball filename "
        "is selected per-tier in RunConfig below."
    )
# Out:
# Mounted at /content/drive
# [OK] Drive mount: /content/drive
# [OK] Synthea source: /content/drive/MyDrive/kubuntu/agentic-memory/big-healtcare-data/synthetic-data
# [OK] Experiment dir: /content/drive/MyDrive/kubuntu/agentic-memory/experiments/healthcare
# [OK] Checkpoints: /content/drive/MyDrive/kubuntu/agentic-memory/experiments/healthcare/checkpoints
# [OK] Results: /content/drive/MyDrive/kubuntu/agentic-memory/experiments/healthcare/results

# %%
"""Ensure the agentic-memory source tree is available.

**Google Colab:** clone or upload to ``/content/agentic-memory``.

**Local (Cursor / VS Code):** open the repository **folder** as the workspace
(the directory that contains ``pyproject.toml``). This cell discovers that
path by walking upward from the process working directory, so it works on
Windows and macOS — not only ``/content/...`` paths.

Either way, the cell finishes with ``PYTHONPATH`` including
``<repo>/src`` and ``chdir`` set to the repo root.
"""
import os
import subprocess
import sys
from pathlib import Path

REPO_URL = "https://github.com/jarmen423/agentic-memory.git"
REPO_REF = "main"
COLAB_REPO = Path("/content/agentic-memory")


def _find_repo_root() -> Path | None:
    """Return repo root if already on disk, else None.

    Prefer Colab's standard tree when present, then walk upward from cwd
    looking for ``pyproject.toml`` plus ``src/agentic_memory/``.
    """
    if COLAB_REPO.is_dir() and (COLAB_REPO / "pyproject.toml").is_file():
        return COLAB_REPO.resolve()
    here = Path.cwd().resolve()
    for base in [here, *here.parents]:
        if (base / "pyproject.toml").is_file() and (base / "src" / "agentic_memory").is_dir():
            return base
    return None


def _is_git_repo(path: Path) -> bool:
    """True if *path* looks like a git working tree (has .git/ or is in one)."""
    if not path.is_dir():
        return False
    if (path / ".git").exists():
        return True
    # Uploaded trees often omit .git/. Treat a matching source layout as ok.
    return (path / "src" / "agentic_memory" / "__init__.py").exists()


_found = _find_repo_root()
if _found is not None:
    REPO_DIR = _found
    print(f"Using repo at {REPO_DIR} (local workspace or existing Colab tree)")
elif Path("/content").is_dir():
    # Fresh Colab runtime: clone into the standard scratch path
    REPO_DIR = COLAB_REPO
else:
    raise RuntimeError(
        "Cannot find the agentic-memory repository.\n"
        "• Local: use File → Open Folder on the repo root (folder with "
        "pyproject.toml), then re-run this cell.\n"
        "• Colab: use a runtime with /content and let this cell clone."
    )

if _is_git_repo(REPO_DIR):
    # Already present — either uploaded from Cursor or cloned on a prior run.
    if (REPO_DIR / ".git").exists():
        print(f"Repo already present at {REPO_DIR}; pulling latest {REPO_REF}")
        try:
            subprocess.check_call(["git", "-C", str(REPO_DIR), "fetch", "--all", "--tags"])
            subprocess.check_call(["git", "-C", str(REPO_DIR), "checkout", REPO_REF])
            subprocess.check_call(["git", "-C", str(REPO_DIR), "pull", "--ff-only"])
        except subprocess.CalledProcessError as exc:
            # An uploaded tree with local edits may refuse a fast-forward pull.
            # That is usually what the user wants; print a warning and carry on.
            print(f"git pull skipped ({exc}); using the existing tree as-is.")
    else:
        print(f"Repo detected at {REPO_DIR} (uploaded; no .git/). Using as-is.")
else:
    print(f"Cloning {REPO_URL}@{REPO_REF} into {REPO_DIR}")
    subprocess.check_call(["git", "clone", REPO_URL, str(REPO_DIR)])
    subprocess.check_call(["git", "-C", str(REPO_DIR), "checkout", REPO_REF])

# Record the HEAD commit in the notebook output for reproducibility (when
# possible; uploaded trees may not have a .git dir).
try:
    commit = subprocess.check_output(
        ["git", "-C", str(REPO_DIR), "rev-parse", "--short", "HEAD"], text=True
    ).strip()
    print(f"Repo at commit {commit}")
except subprocess.CalledProcessError:
    print("Repo has no git metadata (uploaded tree); skipping commit fingerprint.")

os.environ["PYTHONPATH"] = f"{REPO_DIR}/src:{os.environ.get('PYTHONPATH', '')}"
os.chdir(REPO_DIR)
# Out:
# Using repo at /content/agentic-memory (local workspace or existing Colab tree)
# Repo already present at /content/agentic-memory; pulling latest main
# Repo at commit ca3dcfe

# %%
"""Install Python dependencies.

We install the project itself plus the GPU embedding stack. Neo4j and
SpacetimeDB clients are pulled in by the project's own requirements.

The `transformers` + `accelerate` + `sentencepiece` trio is what the
Nemotron embedding model needs on GPU. `bitsandbytes` is included for
optional 8-bit quantisation if GPU memory is tight on a T4.

**Local Cursor:** ``pip install -e`` must target your real repo path, not
``/content/...`` (that path is Colab-only).
"""
import subprocess
import sys
from pathlib import Path

COLAB_REPO = Path("/content/agentic-memory")


def _repo_root() -> Path:
    if COLAB_REPO.is_dir() and (COLAB_REPO / "pyproject.toml").is_file():
        return COLAB_REPO.resolve()
    here = Path.cwd().resolve()
    for base in [here, *here.parents]:
        if (base / "pyproject.toml").is_file() and (base / "src" / "agentic_memory").is_dir():
            return base
    raise RuntimeError(
        "Could not find repo root. Run the previous 'clone / repo' cell, or "
        "open the agentic-memory folder in Cursor as the workspace root."
    )


REPO_DIR = _repo_root()

# Editable install so `import agentic_memory` resolves (same interpreter).
subprocess.check_call(
    [sys.executable, "-m", "pip", "install", "-q", "-e", str(REPO_DIR)],
)

# GPU embedding stack. Pinning major versions avoids Colab's preinstalled
# torch getting blown away by a conflicting transformers release.
subprocess.check_call([
    sys.executable, "-m", "pip", "install", "-q",
    "transformers>=4.44",
    "accelerate>=0.33",
    "sentencepiece>=0.2",
    "einops>=0.8",
])

print("Python dependencies installed.")
# Out:
# Python dependencies installed.

# %% [markdown]
# ## Section 3 — Tailscale bridge
#
# The Neo4j instance lives on a private Tailscale IP on our experiment VM.
# Colab is on the public internet with no Tailscale client installed by
# default, so we install Tailscale *inside* the Colab runtime in userspace
# mode (no TUN device, no root kernel modules — just a SOCKS proxy and
# a routing daemon).
#
# This cell:
#
# 1. Downloads the Tailscale binary for Linux x86_64.
# 2. Starts `tailscaled --tun=userspace-networking` as a background process.
# 3. Runs `tailscale up` with the pre-authorised key from Colab Secrets.
# 4. Waits until the Colab node shows a Tailscale IPv4.
#
# After this cell runs, the Neo4j host's Tailscale IP is reachable from
# Python via `neo4j.GraphDatabase.driver(os.environ["NEO4J_URI"])`. No
# kernel tweaks, no port forwards, no public Bolt exposure.
#
# **Why userspace networking:** Colab runtimes do not permit creating TUN
# devices. Tailscale's userspace mode works around this by routing all
# Tailscale traffic through the daemon itself. The daemon exposes a local
# SOCKS5 proxy we could use for other protocols, but the Neo4j bolt driver
# connects directly via the userspace-netstack so no proxy config is needed
# for our use case. Throughput is capped around ~100 Mbps which is well
# above what we need for batched embedding writes.

# %%
"""Install the Tailscale binary into the Colab runtime.

We pull the static Linux x86_64 release rather than the apt package
because Colab's apt sources don't include it by default and adding a
third-party repo just to get one binary is unnecessary churn.
"""
import subprocess
import urllib.request
from pathlib import Path

TAILSCALE_VERSION = "1.72.1"
TAILSCALE_TARBALL = f"tailscale_{TAILSCALE_VERSION}_amd64.tgz"
TAILSCALE_URL = f"https://pkgs.tailscale.com/stable/{TAILSCALE_TARBALL}"

WORKDIR = Path("/content/tailscale-bin")
WORKDIR.mkdir(parents=True, exist_ok=True)

tarball_path = WORKDIR / TAILSCALE_TARBALL
if not tarball_path.exists():
    print(f"Downloading {TAILSCALE_URL}")
    urllib.request.urlretrieve(TAILSCALE_URL, tarball_path)

subprocess.check_call(["tar", "-xzf", str(tarball_path), "-C", str(WORKDIR), "--strip-components=1"])

TAILSCALE_BIN = WORKDIR / "tailscale"
TAILSCALED_BIN = WORKDIR / "tailscaled"

for binary in (TAILSCALE_BIN, TAILSCALED_BIN):
    if not binary.exists():
        raise RuntimeError(f"Tailscale extraction failed; {binary} missing.")

print(f"Tailscale {TAILSCALE_VERSION} installed at {WORKDIR}")
# Out:
# Tailscale 1.72.1 installed at /content/tailscale-bin

# %%
"""Start the Tailscale daemon in userspace mode and join the tailnet.

The daemon runs for the lifetime of the Colab session. If the session
restarts, this cell must be re-run — which is fine; `tailscale up --authkey`
with an ephemeral key is idempotent and cheap.

Secrets resolution:
  We define a small get_secret() helper here (also used by the config
  cell further down) that adapts to whichever runtime we're in. It tries
  Colab Secrets with a timeout, then os.environ, then any dotenv file
  uploaded to /content. This is the one-stop fallback chain: set the
  secret in ANY of those places and it gets picked up.
"""
import os
import subprocess
import threading
import time
from pathlib import Path
from typing import Optional


# Candidate dotenv paths the helper will scan once, in order. The first
# matching file populates os.environ for any key not already set.
_SECRETS_FILE_CANDIDATES = [
    Path("/content/secrets.env"),
    Path("/content/.env"),
    Path("/content/agentic-memory/experiments/healthcare/.env"),
]

_SECRETS_CACHE: dict[str, str] = {}
_DOTENV_LOADED = False


def _try_colab_userdata(name: str, timeout: float = 2.0) -> Optional[str]:
    """Try google.colab.userdata.get() with a short timeout.

    Works instantly in the Colab web UI. Hangs indefinitely in the
    VSCode Colab extension (issue googlecolab/colab-vscode#215), so
    we thread-join-with-timeout to avoid deadlocking the notebook.
    """
    try:
        from google.colab import userdata  # type: ignore[import-not-found]
    except ImportError:
        return None

    result: dict[str, Optional[str]] = {"value": None}

    def _worker() -> None:
        try:
            result["value"] = userdata.get(name)  # type: ignore[attr-defined]
        except Exception:  # noqa: BLE001 — all failures fall through to next source
            result["value"] = None

    thread = threading.Thread(target=_worker, daemon=True)
    thread.start()
    thread.join(timeout=timeout)
    if thread.is_alive():
        return None
    return result["value"] or None


def _load_dotenv_files_once() -> None:
    """Populate os.environ from the first dotenv file found in /content.

    Run at most once per session. `setdefault` means we never overwrite
    a value already set by an earlier cell or by Colab Secrets.
    """
    global _DOTENV_LOADED
    if _DOTENV_LOADED:
        return
    _DOTENV_LOADED = True

    for candidate in _SECRETS_FILE_CANDIDATES:
        if not candidate.exists():
            continue
        for raw_line in candidate.read_text().splitlines():
            line = raw_line.strip()
            if not line or line.startswith("#"):
                continue
            if "=" not in line:
                continue
            key, value = line.split("=", 1)
            os.environ.setdefault(key.strip(), value.strip().strip('"').strip("'"))
        print(f"Loaded secrets from {candidate}")
        return


def get_secret(
    name: str,
    *,
    required: bool = True,
    aliases: tuple[str, ...] = (),
) -> Optional[str]:
    """Return a secret by name with a runtime-adaptive fallback chain.

    Resolution order (tried for `name`, then each alias in turn):
      1. Process environment (set by prior cells or by the host shell).
      2. Colab Secrets via userdata.get() with a 2 s timeout.
      3. First matching dotenv file in /content (uploaded by user).

    Args:
        name: Secret key (e.g. "NEO4J_URI").
        required: Raise RuntimeError if the secret cannot be resolved.

    Returns:
        The secret value or None if missing and not required.
    """
    # Try the canonical name first, then any declared aliases. Each
    # key goes through the same env -> userdata -> dotenv fallback.
    candidates = (name, *aliases)

    for key in candidates:
        if key in _SECRETS_CACHE:
            _SECRETS_CACHE[name] = _SECRETS_CACHE[key]
            return _SECRETS_CACHE[key]

    _load_dotenv_files_once()

    for key in candidates:
        value = os.environ.get(key)
        if value:
            _SECRETS_CACHE[name] = value
            os.environ[name] = value
            return value

    for key in candidates:
        value = _try_colab_userdata(key)
        if value:
            _SECRETS_CACHE[name] = value
            os.environ[name] = value
            return value

    if required:
        tried = ", ".join(candidates)
        raise RuntimeError(
            f"Secret {name!r} not found in any source (tried {tried}). "
            "Set it via one of:\n"
            "  - Colab Secrets sidebar (web UI only)\n"
            "  - A dotenv file at /content/secrets.env or an uploaded .env\n"
            "  - os.environ[KEY] = ... in a cell above this one"
        )
    return None


AUTHKEY = get_secret("TAILSCALE_AUTH_KEY", aliases=("TAILSCALE_AUTHKEY",))
if not AUTHKEY:
    raise RuntimeError(
        "TAILSCALE_AUTHKEY could not be resolved. "
        "Generate an ephemeral pre-authorised key in the Tailscale admin console "
        "with tag tag:colab, then set it via Colab Secrets or /content/secrets.env."
    )

# Reset any stale tailscaled state from a previous (partial) run in this
# session. A prior daemon may have left a Unix socket bound at
# /content/tailscale-state/tailscaled.sock, which causes the next startup
# to fail with "safesocket.Listen: address already in use" and exit code 1.
# Killing any leftover process and removing the socket/state/log makes
# the daemon cell idempotent across re-runs.
subprocess.run(["pkill", "-f", "tailscaled"], check=False)

STATE_DIR = Path("/content/tailscale-state")
for stale in (
    STATE_DIR / "tailscaled.sock",
    STATE_DIR / "tailscaled.state",
    STATE_DIR / "tailscaled.log",
):
    try:
        stale.unlink()
    except FileNotFoundError:
        pass

STATE_DIR.mkdir(parents=True, exist_ok=True)

TAILSCALE_SOCK = STATE_DIR / "tailscaled.sock"

daemon_cmd = [
    str(TAILSCALED_BIN),
    "--tun=userspace-networking",
    f"--socket={TAILSCALE_SOCK}",
    f"--state={STATE_DIR / 'tailscaled.state'}",
    "--socks5-server=localhost:1055",
]

daemon_log = open(STATE_DIR / "tailscaled.log", "w", buffering=1)
daemon_proc = subprocess.Popen(
    daemon_cmd,
    stdout=daemon_log,
    stderr=subprocess.STDOUT,
    cwd=str(STATE_DIR),
)

time.sleep(2)
if daemon_proc.poll() is not None:
    raise RuntimeError(
        f"tailscaled exited immediately (code {daemon_proc.returncode}). "
        f"Check {STATE_DIR / 'tailscaled.log'}."
    )

up_cmd = [
    str(TAILSCALE_BIN),
    f"--socket={TAILSCALE_SOCK}",
    "up",
    f"--authkey={AUTHKEY}",
    "--hostname=colab-experiment-runner",
    "--accept-routes",
    "--ssh=false",
]
subprocess.check_call(up_cmd)

status_out = subprocess.check_output(
    [str(TAILSCALE_BIN), f"--socket={TAILSCALE_SOCK}", "ip", "-4"],
    text=True,
)
tailscale_ip = status_out.strip().splitlines()[0]
print(f"Colab node joined tailnet. Tailscale IPv4 = {tailscale_ip}")
# Out:
# Loaded secrets from /content/secrets.env
# Colab node joined tailnet. Tailscale IPv4 = 100.103.151.41

# %% [markdown]
# ## Section 4 — Configuration
#
# One cell, one `RunConfig` dataclass, one source of truth for every
# setting that downstream cells read. Putting all knobs in one place
# means:
#
# - The notebook's behaviour for a given tier is auditable at a glance.
# - Re-running a subset of cells after tweaking a single value (e.g.
#   batch size) doesn't require hunting through a dozen spots.
# - The same config pattern can be serialised to a JSON alongside results
#   for reproducibility.
#
# **Pick the tier here.** Every other setting is derived.

# %%
"""Build the RunConfig for this notebook invocation.

Tiers map to the scale-ladder from Plan B (synthea-experiments-scale.md):
    smoke  — 2,000 patients
    mid    — 20,000 patients
    scale  — 200,000 patients
    full   — 1,000,000 patients (research-credit VM only; not typical for Colab)

Change TIER below to pick a run. Everything else follows.
"""
from dataclasses import dataclass, field, asdict
from pathlib import Path
from typing import Literal
import json
import os

# get_secret() was defined in the Tailscale cell above. If you re-ran
# cells out of order and hit NameError here, re-run that cell first.

Tier = Literal["smoke", "mid", "scale", "full"]

TIER: Tier = "smoke"


@dataclass
class RunConfig:
    """Per-run settings for a single tier of the scale ladder.

    Attributes:
        tier: Which tier of the ladder we are running.
        max_patients: Upper bound on unique patients ingested from the tarball.
        checkpoint_every: How many patients between checkpoint writes.
        embed_batch_size: Records per GPU embedding batch.
        neo4j_write_batch_size: Records per Neo4j UNWIND batch.
        embedding_dim: Target embedding dimension for the vector index.
        source_tarball: Path to the FHIR tarball on mounted Drive.
        project_id: SpacetimeDB project namespace; identifies this experiment's claims.
        checkpoint_path: Where to persist last-processed-patient state on Drive.
        results_path: Where to write the per-tier result JSON.
    """

    tier: Tier
    max_patients: int
    checkpoint_every: int
    embed_batch_size: int
    neo4j_write_batch_size: int
    embedding_dim: int
    source_tarball: Path
    project_id: str
    checkpoint_path: Path
    results_path: Path


_TIER_PRESETS: dict[Tier, dict] = {
    "smoke": {
        "max_patients": 2_000,
        "checkpoint_every": 250,
        "embed_batch_size": 64,
        "neo4j_write_batch_size": 500,
        "source_tarball_name": "synthea_2017_02_27.tar.gz",
    },
    "mid": {
        "max_patients": 20_000,
        "checkpoint_every": 1_000,
        "embed_batch_size": 128,
        "neo4j_write_batch_size": 1_000,
        "source_tarball_name": "synthea_2017_02_27.tar.gz",
    },
    "scale": {
        "max_patients": 200_000,
        "checkpoint_every": 2_000,
        "embed_batch_size": 128,
        "neo4j_write_batch_size": 1_000,
        "source_tarball_name": "synthea_1m_fhir_3_0_May_24.tar.gz",
    },
    "full": {
        "max_patients": 1_000_000,
        "checkpoint_every": 5_000,
        "embed_batch_size": 256,
        "neo4j_write_batch_size": 2_000,
        "source_tarball_name": "synthea_1m_fhir_3_0_May_24.tar.gz",
    },
}


def build_run_config(tier: Tier) -> RunConfig:
    preset = _TIER_PRESETS[tier]
    return RunConfig(
        tier=tier,
        max_patients=preset["max_patients"],
        checkpoint_every=preset["checkpoint_every"],
        embed_batch_size=preset["embed_batch_size"],
        neo4j_write_batch_size=preset["neo4j_write_batch_size"],
        embedding_dim=2048,  # matches default nemotron_local model (nvidia/llama-nemotron-embed-vl-1b-v2); reconciled in the embedding cell
        source_tarball=SYNTHEA_DIR / preset["source_tarball_name"],
        project_id=f"synthea-scale-{tier}",
        checkpoint_path=CHECKPOINT_DIR / f"{tier}.json",
        results_path=RESULTS_DIR / f"ingest_{tier}.json",
    )


CONFIG = build_run_config(TIER)

# Surface Neo4j and SpacetimeDB secrets into the process environment so the
# existing agentic_memory modules (which read os.environ) work without changes.
# NVIDIA_API_KEY is optional — only needed if we fall back to the hosted
# Nemotron endpoint instead of the local-GPU provider.
# Canonical name -> aliases accepted in dotenv/env (user .env uses
# _USERNAME; Neo4j driver historically uses _USER; we take either).
_REQUIRED_SECRETS: dict[str, tuple[str, ...]] = {
    "NEO4J_URI": (),
    "NEO4J_USER": ("NEO4J_USERNAME",),
    "NEO4J_PASSWORD": (),
    "STDB_URI": (),
    "STDB_TOKEN": (),
    "STDB_BINDINGS_MODULE": (),
}
_OPTIONAL_SECRETS: dict[str, tuple[str, ...]] = {
    "NVIDIA_API_KEY": (),
}

for secret_key, aliases in _REQUIRED_SECRETS.items():
    value = get_secret(secret_key, required=True, aliases=aliases)
    # get_secret() already pushed the value into os.environ on resolution.
    assert value, f"Required secret {secret_key} resolved empty"

for secret_key, aliases in _OPTIONAL_SECRETS.items():
    value = get_secret(secret_key, required=False, aliases=aliases)
    if value:
        os.environ[secret_key] = value

os.environ["EMBEDDING_PROVIDER"] = "nemotron_local"

print(json.dumps(
    {k: str(v) for k, v in asdict(CONFIG).items()},
    indent=2,
    default=str,
))

if not CONFIG.source_tarball.exists():
    raise RuntimeError(
        f"Source tarball not found on Drive: {CONFIG.source_tarball}\n"
        "Confirm Drive is mounted and the tarball path matches your layout."
    )
# Out:
# {
#   "tier": "smoke",
#   "max_patients": "2000",
#   "checkpoint_every": "250",
#   "embed_batch_size": "64",
#   "neo4j_write_batch_size": "500",
#   "embedding_dim": "1024",
#   "source_tarball": "/content/drive/MyDrive/kubuntu/agentic-memory/big-healtcare-data/synthetic-data/synthea_2017_02_27.tar.gz",
#   "project_id": "synthea-scale-smoke",
#   "checkpoint_path": "/content/drive/MyDrive/kubuntu/agentic-memory/experiments/healthcare/checkpoints/smoke.json",
#   "results_path": "/content/drive/MyDrive/kubuntu/agentic-memory/experiments/healthcare/results/ingest_smoke.json"
# }

# %% [markdown]
# ## Section 5 — Connectivity preflight
#
# **First cell below** ensures `agentic_memory` imports (re-runs editable install if you restarted the kernel).
#
# Long ingest runs fail expensively. Before we load any models or touch
# any data, confirm we can reach every external dependency:
#
# - **Neo4j** over Bolt on the Tailscale IP.
# - **SpacetimeDB Maincloud** via the `TemporalBridge` RPC.
# - **Drive tarball** readable (already checked above, but we also try
#   cracking it open here to confirm the FHIR loader's lazy-iter path
#   works).
#
# Any one of these failing means we stop now, fix it on the host side,
# and resume. We do not try to ingest partially.

# %%
"""Make ``agentic_memory`` importable in this kernel.

Section 2 runs ``pip install -e <repo>``, which registers the package for the
**current interpreter only**. After restarting the Jupyter kernel, re-run the
install cell.

This cell is a safety net:

1. Resolves the repo root (Colab ``/content/agentic-memory`` **or** your local
   workspace by walking up from ``cwd`` for ``pyproject.toml``).
2. Prepends ``<repo>/src`` to ``sys.path``.
3. If import still fails, runs ``pip install -e`` once against that root.

Run this **before** any cell that does ``from agentic_memory...``.
"""
import importlib
import subprocess
import sys
from pathlib import Path

COLAB_REPO = Path("/content/agentic-memory")


def _repo_root() -> Path:
    if COLAB_REPO.is_dir() and (COLAB_REPO / "pyproject.toml").is_file():
        return COLAB_REPO.resolve()
    here = Path.cwd().resolve()
    for base in [here, *here.parents]:
        if (base / "pyproject.toml").is_file() and (base / "src" / "agentic_memory").is_dir():
            return base
    raise RuntimeError(
        "Could not find repo root. Run Section 2 clone + install, or open the "
        "agentic-memory folder in Cursor (workspace = folder with pyproject.toml)."
    )


REPO_DIR = _repo_root()
_SRC = REPO_DIR / "src"

if _SRC.is_dir() and str(_SRC) not in sys.path:
    sys.path.insert(0, str(_SRC))

try:
    importlib.import_module("agentic_memory")
except ModuleNotFoundError:
    subprocess.check_call(
        [sys.executable, "-m", "pip", "install", "-q", "-e", str(REPO_DIR)],
    )
    importlib.import_module("agentic_memory")

print(f"[ok] agentic_memory is importable (repo={REPO_DIR})")
# Out:
# [ok] agentic_memory is importable (repo=/content/agentic-memory)

# %%
"""Route Bolt traffic through tailscaled's SOCKS5 proxy (bolt-proxy-cell-v1).

The Colab Tailscale daemon uses ``--tun=userspace-networking``; it does
NOT install kernel routes for tailnet IPs. The Neo4j driver uses plain
sockets, so connecting directly to the VM's tailnet IP times out. This
cell starts a tiny in-process TCP forwarder that accepts on
``127.0.0.1:17687`` and pipes each connection through the SOCKS5 proxy
on ``127.0.0.1:1055`` to the real Neo4j host. ``NEO4J_URI`` is then
rewritten to point at the local forwarder, so downstream
``ConnectionManager`` calls work without modification.

Safe to re-run: the prior listener is shut down before a new one binds.
"""
import os
import socket
import socketserver
import subprocess
import threading
import time
from contextlib import closing
from urllib.parse import urlparse

_LOCAL_PORT = 17687
_SOCKS_HOST = "127.0.0.1"
_SOCKS_PORT = 1055


def _parse_bolt_target(uri: str) -> tuple[str, int]:
    """Extract host/port from a bolt[+s]:// URI.

    Args:
        uri: Value of ``NEO4J_URI`` loaded from Colab Secrets.

    Returns:
        (host, port) tuple ready for a SOCKS5 CONNECT.
    """
    parsed = urlparse(uri)
    if not parsed.hostname:
        raise RuntimeError(f"NEO4J_URI is malformed: {uri!r}")
    return parsed.hostname, int(parsed.port or 7687)


def _install_pysocks() -> None:
    """Pull PySocks at runtime if not already present."""
    try:
        import socks  # noqa: F401
    except ImportError:
        subprocess.check_call(["pip", "install", "-q", "PySocks"])


def _pipe(src: socket.socket, dst: socket.socket) -> None:
    """Shovel bytes one direction until either side closes.

    Keeping this tiny avoids surprises: no buffering games, no frame
    parsing - the SOCKS5 tunnel already handles the wire.
    """
    try:
        while True:
            data = src.recv(65536)
            if not data:
                break
            dst.sendall(data)
    except OSError:
        pass
    finally:
        try:
            dst.shutdown(socket.SHUT_WR)
        except OSError:
            pass


_REMOTE_HOST, _REMOTE_PORT = _parse_bolt_target(os.environ["NEO4J_URI"])


class _SocksProxyHandler(socketserver.BaseRequestHandler):
    """Per-connection handler that opens a matching SOCKS5 tunnel."""

    def handle(self) -> None:
        import socks  # PySocks

        upstream = socks.socksocket()
        upstream.set_proxy(socks.SOCKS5, _SOCKS_HOST, _SOCKS_PORT)
        upstream.settimeout(30)
        try:
            upstream.connect((_REMOTE_HOST, _REMOTE_PORT))
        except Exception as exc:  # noqa: BLE001
            print(f"[bolt-proxy] upstream connect failed: {exc}")
            return

        t_out = threading.Thread(
            target=_pipe, args=(self.request, upstream), daemon=True
        )
        t_in = threading.Thread(
            target=_pipe, args=(upstream, self.request), daemon=True
        )
        t_out.start(); t_in.start()
        t_out.join(); t_in.join()
        with closing(upstream):
            pass


class _ThreadedTCPServer(socketserver.ThreadingMixIn, socketserver.TCPServer):
    """Daemon-threaded TCP server, safe to shutdown on cell re-run."""
    allow_reuse_address = True
    daemon_threads = True


_install_pysocks()

# Tear down any prior listener so this cell is safe to re-run.
if "_BOLT_PROXY_SERVER" in globals():
    try:
        _BOLT_PROXY_SERVER.shutdown()  # type: ignore[name-defined]
        _BOLT_PROXY_SERVER.server_close()  # type: ignore[name-defined]
    except Exception:
        pass

_BOLT_PROXY_SERVER = _ThreadedTCPServer(
    ("127.0.0.1", _LOCAL_PORT), _SocksProxyHandler
)
_BOLT_PROXY_THREAD = threading.Thread(
    target=_BOLT_PROXY_SERVER.serve_forever, daemon=True
)
_BOLT_PROXY_THREAD.start()
time.sleep(0.5)

os.environ["NEO4J_URI"] = f"bolt://127.0.0.1:{_LOCAL_PORT}"
print(
    f"Bolt proxy listening on 127.0.0.1:{_LOCAL_PORT} -> "
    f"socks5://{_SOCKS_HOST}:{_SOCKS_PORT} -> {_REMOTE_HOST}:{_REMOTE_PORT}"
)
print(f"NEO4J_URI overridden to {os.environ['NEO4J_URI']}")
# Out:
# Bolt proxy listening on 127.0.0.1:17687 -> socks5://127.0.0.1:1055 -> 127.0.0.1:17687
# NEO4J_URI overridden to bolt://127.0.0.1:17687

# %%
"""Preflight: Neo4j connectivity over Tailscale.

Runs the cheapest possible query that exercises the full client path:
driver handshake + authentication + one trivial Cypher roundtrip. If
this passes, the host is reachable and the credentials work.
"""
import os

from neo4j import GraphDatabase

driver = GraphDatabase.driver(
    os.environ["NEO4J_URI"],
    auth=(os.environ["NEO4J_USER"], os.environ["NEO4J_PASSWORD"]),
)

try:
    with driver.session() as session:
        result = session.run("RETURN 1 AS ok").single()
        assert result and result["ok"] == 1
    print(f"Neo4j OK — {os.environ['NEO4J_URI']}")
finally:
    driver.close()
# Out:
# ----------------------------------------
# Exception occurred during processing of request from ('127.0.0.1', 36058)
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/socketserver.py", line 697, in process_request_thread
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.12/socketserver.py", line 362, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.12/socketserver.py", line 766, in __init__
#     self.handle()
#   File "/tmp/ipykernel_8947/217887908.py", line 96, in handle
#     t_out.start(); t_in.start()
#                    ^^^^^^^^^^^^
#   File "/usr/lib/python3.12/threading.py", line 994, in start
#     _start_new_thread(self._bootstrap, ())
# RuntimeError: can't start new thread
# ----------------------------------------
# ---------------------------------------------------------------------------
# ServiceUnavailable                        Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/io/_bolt_socket.py in connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     335                 )
# --> 336                 agreed_version = s._handshake(resolved_address, deadline)
#     337                 return s, agreed_version
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/io/_bolt_socket.py in _handshake(self, resolved_address, deadline)
#     262         ctx.ctx = "four byte Bolt handshake response"
# --> 263         response = self._handshake_read(ctx, 4)
#     264
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/io/_bolt_socket.py in _handshake_read(self, ctx, n)
#     180             self.close()
# --> 181             raise ServiceUnavailable(
#     182                 f"Connection to {ctx.resolved_address} closed with incomplete "
#
# ServiceUnavailable: Connection to 127.0.0.1:17687 closed with incomplete handshake response
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# /tmp/ipykernel_8947/1889577772.py in <cell line: 0>()
#      16 try:
#      17     with driver.session() as session:
# ---> 18         result = session.run("RETURN 1 AS ok").single()
#      19         assert result and result["ok"] == 1
#      20     print(f"Neo4j OK — {os.environ['NEO4J_URI']}")
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/work/session.py in run(self, query, parameters, **kwargs)
#     303
#     304         if not self._connection:
# --> 305             self._connect(self._config.default_access_mode)
#     306             assert self._connection is not None
#     307         cx = self._connection
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/work/session.py in _connect(self, access_mode, **acquire_kwargs)
#     124             access_mode = self._config.default_access_mode
#     125         try:
# --> 126             super()._connect(
#     127                 access_mode, auth=self._config.auth, **acquire_kwargs
#     128             )
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/work/workspace.py in _connect(self, access_mode, auth, **acquire_kwargs)
#     179         }
#     180         acquire_kwargs_.update(acquire_kwargs)
# --> 181         self._connection = self._pool.acquire(**acquire_kwargs_)
#     182         if (
#     183             target_db.guessed
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/io/_pool.py in acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout, unprepared, database_callback)
#     676             database,
#     677         )
# --> 678         return self._acquire(
#     679             self.address, auth, deadline, liveness_check_timeout, unprepared
#     680         )
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/io/_pool.py in _acquire(self, address, auth, deadline, liveness_check_timeout, unprepared)
#     416                     )
#     417         log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 418         return connection_creator()
#     419
#     420     @abc.abstractmethod
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/io/_pool.py in connection_creator()
#     229             try:
#     230                 try:
# --> 231                     connection = self.opener(
#     232                         address, auth or self.pool_config.auth, deadline
#     233                     )
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/io/_pool.py in opener(addr, auth_manager, deadline)
#     636
#     637         def opener(addr, auth_manager, deadline):
# --> 638             return Bolt.open(
#     639                 addr,
#     640                 auth_manager=auth_manager,
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/io/_bolt.py in open(address, auth_manager, deadline, routing_context, pool_config)
#     366             deadline = Deadline(None)
#     367
# --> 368         s, protocol_version = BoltSocket.connect(
#     369             address,
#     370             tcp_timeout=pool_config.connection_timeout,
#
# /usr/local/lib/python3.12/dist-packages/neo4j/_sync/io/_bolt_socket.py in connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     378         else:
#     379             error_strs = "\n".join(map(str, errors))
# --> 380             raise ServiceUnavailable(
#     381                 f"Couldn't connect to {address} (resolved to {address_strs}):"
#     382                 f"\n{error_strs}"
#
# ServiceUnavailable: Couldn't connect to 127.0.0.1:17687 (resolved to ('127.0.0.1:17687',)):
# Connection to 127.0.0.1:17687 closed with incomplete handshake response

# %%
"""Preflight: SpacetimeDB Maincloud connectivity via TemporalBridge.

The bridge spawns a Node helper subprocess. We call is_available()
which internally performs a handshake — this surfaces the JSONDecodeError
we hit in preflight_checks.py if the Phase 0 fix isn't merged yet.

If this cell fails, check:
  1. STDB_BINDINGS_MODULE is an absolute path that exists.
  2. The Phase 0 bridge fix is merged (lines near _ensure_process).
  3. Maincloud is reachable at STDB_URI.
"""
from agentic_memory.temporal.bridge import TemporalBridge

_bridge = TemporalBridge.from_env()

if not _bridge.is_available():
    raise RuntimeError(
        f"SpacetimeDB bridge unavailable: {_bridge.disabled_reason}. "
        "Confirm STDB_URI/STDB_TOKEN/STDB_BINDINGS_MODULE secrets are set "
        "and Phase 0 bridge fixes are merged."
    )

print("SpacetimeDB bridge OK")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_8947/1675398583.py in <cell line: 0>()
#      10   3. Maincloud is reachable at STDB_URI.
#      11 """
# ---> 12 from agentic_memory.temporal.bridge import TemporalBridge
#      13
#      14 _bridge = TemporalBridge.from_env()
#
# ModuleNotFoundError: No module named 'agentic_memory'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
"""Preflight: FHIR loader can open the tarball and yield the first patient.

This is the cheapest way to confirm:
  1. Drive is still mounted (Colab sometimes silently unmounts).
  2. The Phase 0 lazy-iter patch to fhir_loader.py is in effect —
     the unpatched loader calls outer.getmembers() which takes 15+ min
     on a 30 GB Drive-streamed archive. If this preflight takes more
     than ~60 seconds the patch is NOT applied.
  3. Bundles actually parse as FHIR R4.

We only read one patient. Full streaming happens in the ingest section.
"""
import time

from agentic_memory.healthcare.fhir_loader import SyntheaFHIRLoader

# Cap at 1 patient purely to measure "first record" latency without pulling
# the whole tarball into memory. Phase 0 lazy-iter should make this cheap.
_loader = SyntheaFHIRLoader(str(CONFIG.source_tarball), max_patients=1)

start = time.monotonic()
first_record = next(iter(_loader.iter_records()), None)
elapsed = time.monotonic() - start

if first_record is None:
    raise RuntimeError(
        f"FHIR loader returned zero records from {CONFIG.source_tarball}."
    )

print(f"First record yielded in {elapsed:.1f}s")
if elapsed > 60:
    print(
        "WARNING: first-record latency > 60s strongly suggests the Phase 0 "
        "lazy-iter patch is not applied to fhir_loader.py. Long runs will be "
        "much slower than necessary."
    )

print(f"  record_type = {first_record.get('record_type', '<missing>')}")
print(f"  fields present = {sorted(first_record.keys())[:8]}")

# %% [markdown]
# ## Section 6 — Embedding model
#
# Load the Nemotron embedding model onto the GPU **once** per session and
# reuse it for every batch. The existing `EmbeddingService` dispatches on
# `provider="nemotron"` — Phase 0 adds a local-GPU backend so the service
# interface is identical whether you point it at NVIDIA's API or at a
# local `transformers` model.
#
# This cell is heavy (multi-GB model download on first run) and should
# only be run once per Colab session. If you re-run later sections and
# see "model not loaded" errors, re-run this cell.

# %%
"""Build the Nemotron-backed EmbeddingService and warm the GPU.

Uses the Phase 0 ``nemotron_local`` provider, which loads a HuggingFace
text encoder (default: ``nvidia/llama-nemotron-embed-vl-1b-v2``,
2048-dim) onto CUDA and wraps it in the same interface OpenAI/Gemini
providers use.

Override the default model via the ``AM_LOCAL_EMBED_MODEL`` env var if
we switch to an NVIDIA Nemotron retriever checkpoint later. The output
dimension is auto-detected from a warm-up probe, so the Neo4j vector
index dimension (see schema-setup cell) is reconciled to whatever the
loaded model actually produces — no manual dim arithmetic required.

Why this cell runs before schema setup:
    ``ConnectionManager.setup_database(embedding_dim=...)`` needs the
    final dimension at DDL time. Instantiating the embedder here lets
    us read ``embedder.dimensions`` off the live object and push it
    into CONFIG so every downstream cell agrees on the number.
"""
import os

from agentic_memory.core.embedding import EmbeddingService

embedder = EmbeddingService(
    provider="nemotron_local",
    # Both are ignored by the local-GPU backend but harmless to pass. They
    # matter only if we fall back to the hosted Nemotron API provider.
    api_key=os.environ.get("NVIDIA_API_KEY"),
)

# Warm the GPU by embedding a trivial batch. First call typically takes
# 30-90 s because the model weights load into VRAM here. Subsequent
# calls are fast (see Section 9 ingest loop for throughput numbers).
_warm_start_texts = [
    "Condition: Hypertensive disorder, systemic arterial (disorder)",
    "Medication: Lisinopril 10 MG Oral Tablet",
    "Observation: Systolic blood pressure 142 mmHg",
]
_warm_vectors = embedder.embed_batch(_warm_start_texts)

if not _warm_vectors:
    raise RuntimeError("Warm-start embed_batch() returned no vectors.")

detected_dim = len(_warm_vectors[0])

# Reconcile RunConfig.embedding_dim with reality. If the preset was
# wrong (e.g. older notebook runs still claiming 2048), overwrite it
# so setup_database() below creates a matching vector index.
if CONFIG.embedding_dim != detected_dim:
    print(
        f"Embedding dim mismatch: CONFIG was {CONFIG.embedding_dim}, "
        f"model produced {detected_dim}. Updating CONFIG to {detected_dim}."
    )
    CONFIG.embedding_dim = detected_dim

print(f"Nemotron local-GPU embedding service ready. dim={detected_dim}")
print(f"Warm-start produced {len(_warm_vectors)} vectors.")

# %% [markdown]
# ## Section 7 — Schema setup
#
# Bootstrap the Neo4j schema: unique-ID constraints, entity constraints,
# and the `healthcare_embeddings` vector index at our target dimension.
#
# `ConnectionManager.setup_database()` is idempotent. Running it on an
# already-set-up database is a no-op, which is what we want when
# re-running a partially-ingested tier.
#
# **Dimension mismatch is the one thing this will NOT auto-fix.** If the
# index already exists at 3072-dim (the old Gemini default) and CONFIG
# says 2048-dim, Neo4j refuses to silently change the dimension. The cell
# detects this and fails loudly with a remediation hint; we then drop the
# index manually on the Neo4j host and re-run this cell.

# %%
"""Run setup_database() against the experiment Neo4j instance.

The ConnectionManager class manages the Neo4j driver and exposes schema
setup through setup_database(). We pass the target embedding dimension
so the vector index is created at 2048-dim for Nemotron.

Phase 0 extends setup_database() to accept an `embedding_dim` argument.
Until that lands, the default stays at 3072-dim — we detect that
mismatch here rather than discovering it mid-ingest when vector writes
silently truncate.
"""
from agentic_memory.core.connection import ConnectionManager

connection = ConnectionManager(
    os.environ["NEO4J_URI"],
    os.environ["NEO4J_USER"],
    os.environ["NEO4J_PASSWORD"],
)

try:
    connection.setup_database(embedding_dim=CONFIG.embedding_dim)
except TypeError as exc:
    raise RuntimeError(
        "ConnectionManager.setup_database() does not yet accept "
        "embedding_dim — Phase 0 schema change not merged. "
        "Abort this run and land that change first."
    ) from exc

# Verify the index actually came up at the expected dimension.
with connection.driver.session() as session:
    row = session.run(
        """
        SHOW VECTOR INDEXES
        YIELD name, options
        WHERE name = 'healthcare_embeddings'
        RETURN options.indexConfig.`vector.dimensions` AS dim
        """
    ).single()

if row is None:
    raise RuntimeError("healthcare_embeddings index did not come up after setup_database().")

actual_dim = int(row["dim"])
if actual_dim != CONFIG.embedding_dim:
    raise RuntimeError(
        f"healthcare_embeddings index is at {actual_dim}-dim but CONFIG expects "
        f"{CONFIG.embedding_dim}-dim. Drop the index on the host "
        "(DROP INDEX healthcare_embeddings) and re-run this cell."
    )

print(f"Schema OK. healthcare_embeddings vector index at {actual_dim}-dim.")

# %% [markdown]
# ## Section 8 — Checkpoint state
#
# Colab sessions die. 24-hour maximum, shorter on idle, faster on flaky
# runtimes. A tier that takes 8 hours to ingest cannot afford to start
# over every time.
#
# The checkpoint design:
#
# - **Unit of progress is the patient.** We commit a checkpoint after
#   every N patients (N = `CONFIG.checkpoint_every`). Checkpoints do NOT
#   commit mid-patient — a patient is atomic: all of their
#   encounters/conditions/medications/observations/procedures go in
#   together, or they don't.
# - **Checkpoint state** is a JSON file on Drive:
#   `{"tier": "...", "last_patient_id": "...", "patients_done": N, "started_at": "..."}`.
# - **Resume** reads the checkpoint, skips any patient whose ID has
#   already been processed (we track a set of patient IDs in-session),
#   and continues. Neo4j writes are idempotent by deterministic MERGE
#   keys so accidentally re-writing a record is a no-op.
# - **Drive is the source of truth.** We do NOT rely on Neo4j "last
#   patient seen" queries because they'd be slow and Neo4j state lives on
#   a different host than the notebook.

# %%
"""Checkpoint helpers — load and save per-tier progress state on Drive.

The helpers are tiny on purpose. The heavy work is the ingest loop;
checkpoint state is just enough to answer "where do I resume?"
"""
import json
from dataclasses import dataclass, asdict
from datetime import datetime, timezone
from pathlib import Path
from typing import Optional


@dataclass
class CheckpointState:
    """Resumable ingest progress for a single tier.

    Attributes:
        tier: Tier name (matches RunConfig.tier).
        patients_done: Count of patients fully ingested so far.
        last_patient_id: ID of the most recent patient we committed.
            Used for human-readable logs; the skip logic uses the
            processed-IDs set, not this.
        processed_ids: Set of all patient IDs already ingested. Persisted
            so a resumed session can skip them.
        started_at: ISO timestamp of the first session for this tier.
        updated_at: ISO timestamp of the last checkpoint write.
    """

    tier: str
    patients_done: int
    last_patient_id: Optional[str]
    processed_ids: list[str]
    started_at: str
    updated_at: str


def load_checkpoint(path: Path, tier: str) -> CheckpointState:
    """Return the existing checkpoint for this tier, or a fresh empty one.

    Args:
        path: Path to the checkpoint JSON file on Drive.
        tier: Current tier name — used to guard against accidentally
            loading a different tier's checkpoint.

    Returns:
        Loaded CheckpointState, or a new empty one if no file exists.
    """
    if not path.exists():
        now = datetime.now(timezone.utc).isoformat()
        return CheckpointState(
            tier=tier,
            patients_done=0,
            last_patient_id=None,
            processed_ids=[],
            started_at=now,
            updated_at=now,
        )

    raw = json.loads(path.read_text())
    if raw.get("tier") != tier:
        raise RuntimeError(
            f"Checkpoint at {path} is for tier '{raw.get('tier')}', "
            f"not '{tier}'. Move it aside or run the matching tier."
        )

    return CheckpointState(**raw)


def save_checkpoint(path: Path, state: CheckpointState) -> None:
    """Atomically persist a checkpoint to Drive.

    Uses write-to-tmp-then-rename so a Colab crash during the write
    cannot leave a truncated file. Drive's rename is atomic from the
    mounted filesystem's perspective.

    Args:
        path: Target checkpoint file.
        state: Current in-memory checkpoint to persist.
    """
    state.updated_at = datetime.now(timezone.utc).isoformat()
    tmp_path = path.with_suffix(".json.tmp")
    tmp_path.write_text(json.dumps(asdict(state), indent=2))
    tmp_path.replace(path)


checkpoint_state = load_checkpoint(CONFIG.checkpoint_path, CONFIG.tier)
print(
    f"Checkpoint loaded for tier '{CONFIG.tier}': "
    f"{checkpoint_state.patients_done} patients done, "
    f"last = {checkpoint_state.last_patient_id}"
)

# %% [markdown]
# ## Section 9 — Ingest loop
#
# The main event. Reads FHIR records from the source tarball, routes each
# through `HealthcareIngestionPipeline.ingest()`, which handles:
#
# - Generating the memory-node embedding via our Nemotron GPU service.
# - Writing the `:Memory:Healthcare:*` node to Neo4j (idempotent MERGE).
# - Creating entity nodes and edges (patient, provider, diagnosis, etc.)
# - Shadow-writing a temporal claim to SpacetimeDB when the record has a
#   timestamp.
#
# **Patient-atomic checkpointing.** We don't checkpoint between records
# within a patient — only between patients. The FHIR loader already yields
# records grouped by patient, so we detect patient boundaries by watching
# the `PATIENT` field change and checkpoint on boundary crossings once
# `CONFIG.checkpoint_every` boundaries have accumulated.
#
# **Resume behaviour.** On session restart, the checkpoint gives us the
# set of already-processed patient IDs. We stream the tarball from the
# top (no way to seek into a gzip reliably) but skip any record whose
# patient is already in that set. The skip is cheap — no embedding, no
# Neo4j write, just a dict lookup.
#
# **Latency expectations.**
#
# - Smoke (2K): ~20–40 minutes total.
# - Mid (20K): ~2–4 hours.
# - Scale (200K): ~8–16 hours across 1–2 Colab sessions.
#
# The dominant cost is GPU embedding time. Neo4j writes over Tailscale are
# negligible in comparison once batched.

# %%
"""Construct the ingestion pipeline for this run.

Mirrors scripts/ingest_synthea.py's main(): builds the pipeline with
the same services, wired to the Colab-side embedder and the remote
Neo4j instance.

enable_llm_extraction is hard-coded to False here. Structured
entity extraction from FHIR fields is free and deterministic; LLM
extraction is expensive and would cost ~$100+ at the scale tier. If
we ever need LLM extraction for a validation subset we do it from the
CLI script, not Colab.
"""
from agentic_memory.healthcare.pipeline import HealthcareIngestionPipeline

pipeline = HealthcareIngestionPipeline(
    connection_manager=connection,
    embedding_service=embedder,
    entity_extractor=None,
    temporal_bridge=_bridge,
    project_id=CONFIG.project_id,
    enable_llm_extraction=False,
)

print(f"Pipeline ready for project_id='{CONFIG.project_id}'")

# %%
"""Run the ingest loop with patient-atomic checkpointing.

Outer loop: stream FHIR records; group by patient (via the PATIENT
field the FHIR loader puts on every row); ingest each record via the
pipeline; checkpoint after every Nth patient.

Skip-already-processed: on a resumed session, checkpoint_state holds
the set of patient IDs previously committed. Records whose patient is
already in the set are skipped without embedding or Neo4j work.

Stop conditions:
  - max_patients reached (tier-specific cap)
  - FHIR iterator exhausted (reached end of tarball)
  - KeyboardInterrupt (user-initiated stop; checkpoint is flushed)

The loop is long-running (hours on scale tier). We intentionally avoid
any inner-loop tqdm or rich formatting because Colab's output buffer
struggles with dense progress updates over long runs; plain timestamped
prints every batch are more robust.
"""
import logging
import time
from datetime import datetime, timezone

logging.basicConfig(level=logging.INFO, format="%(asctime)s [%(levelname)s] %(message)s")
ingest_logger = logging.getLogger("ingest")

processed_id_set: set[str] = set(checkpoint_state.processed_ids)
current_patient_id: str | None = None
current_patient_records: list[dict] = []

records_seen = 0
records_written = 0
records_errored = 0
temporal_writes = 0
patients_since_checkpoint = 0

run_start = time.monotonic()

loader = SyntheaFHIRLoader(
    str(CONFIG.source_tarball),
    max_patients=CONFIG.max_patients,
)


def _flush_patient(patient_id: str, patient_records: list[dict]) -> tuple[int, int, int]:
    """Ingest all records for one patient through the pipeline.

    We flush a patient as a unit so the checkpoint can treat patients
    as atomic: either every row landed, or we re-do the patient from
    scratch on resume (idempotent MERGEs make this safe).

    Returns (written, errored, temporal_writes).
    """
    written = errored = temporal = 0
    for row in patient_records:
        try:
            result = pipeline.ingest(row)
            written += 1
            if result.get("temporal_written"):
                temporal += 1
        except Exception as exc:  # noqa: BLE001 — keep ingesting on row failure
            errored += 1
            ingest_logger.warning(
                "Failed ingest for patient=%s record_type=%s: %s",
                patient_id, row.get("record_type"), exc,
            )
    return written, errored, temporal


try:
    for record in loader.iter_records():
        records_seen += 1
        patient_id = record.get("PATIENT") or record.get("patient_id") or ""

        # Skip records for patients we already ingested in a prior session.
        if patient_id and patient_id in processed_id_set:
            continue

        # Patient boundary: the loader yields all records for one patient
        # contiguously, so a change in PATIENT means the previous patient
        # is complete.
        if patient_id != current_patient_id:
            if current_patient_id is not None and current_patient_records:
                w, e, t = _flush_patient(current_patient_id, current_patient_records)
                records_written += w
                records_errored += e
                temporal_writes += t

                processed_id_set.add(current_patient_id)
                checkpoint_state.patients_done += 1
                checkpoint_state.last_patient_id = current_patient_id
                patients_since_checkpoint += 1

                if patients_since_checkpoint >= CONFIG.checkpoint_every:
                    checkpoint_state.processed_ids = sorted(processed_id_set)
                    save_checkpoint(CONFIG.checkpoint_path, checkpoint_state)
                    patients_since_checkpoint = 0
                    elapsed_min = (time.monotonic() - run_start) / 60
                    ingest_logger.info(
                        "CHECKPOINT done=%d records_written=%d errors=%d temporal=%d elapsed_min=%.1f",
                        checkpoint_state.patients_done,
                        records_written,
                        records_errored,
                        temporal_writes,
                        elapsed_min,
                    )

            current_patient_id = patient_id
            current_patient_records = []

        current_patient_records.append(record)

    # End-of-stream: flush the final in-progress patient, if any.
    if current_patient_id is not None and current_patient_records:
        w, e, t = _flush_patient(current_patient_id, current_patient_records)
        records_written += w
        records_errored += e
        temporal_writes += t
        processed_id_set.add(current_patient_id)
        checkpoint_state.patients_done += 1
        checkpoint_state.last_patient_id = current_patient_id

except KeyboardInterrupt:
    ingest_logger.warning("User interrupt — flushing final checkpoint before exit.")

finally:
    # Always persist the latest state so partial runs are resumable.
    checkpoint_state.processed_ids = sorted(processed_id_set)
    save_checkpoint(CONFIG.checkpoint_path, checkpoint_state)

total_min = (time.monotonic() - run_start) / 60
print(
    f"\nIngest complete. patients_done={checkpoint_state.patients_done} "
    f"records_seen={records_seen} records_written={records_written} "
    f"errors={records_errored} temporal_writes={temporal_writes} "
    f"elapsed_min={total_min:.1f}"
)

# %% [markdown]
# ## Section 10 — Post-ingest verification
#
# After the ingest loop completes, run a handful of sanity queries
# directly against Neo4j. These are not the real experiments — they just
# catch "ingest silently wrote garbage" failure modes before we invest
# hours in evaluation runs.
#
# The checks:
#
# - **Node counts by label.** If Condition nodes are zero but Encounter
#   nodes are high, something is wrong with the conditions path.
# - **Entity coverage.** Random Patient entities should have outgoing
#   `HAD_ENCOUNTER`, `DIAGNOSED_WITH`, etc. If any patient has zero
#   relationships, we dropped their records on the floor.
# - **Vector index population.** At least one node should have a valid
#   embedding of the expected dimension.
# - **Temporal claim echo.** SpacetimeDB should report the same ballpark
#   of claim counts as Neo4j temporal writes.
#
# All four failing means something major is wrong. Any one passing while
# the others fail usually points at one specific code path to debug.

# %%
"""Run the post-ingest sanity checks and write a results JSON.

Every check prints a one-line result. The full payload is also saved
to CONFIG.results_path so we have a per-tier artifact alongside the
scale curve we eventually plot.
"""
import json
import random
from dataclasses import asdict

checks: dict[str, object] = {
    "tier": CONFIG.tier,
    "patients_done": checkpoint_state.patients_done,
}

with connection.driver.session() as session:
    # Node counts by healthcare record type.
    counts = {}
    for label in ("Encounter", "Condition", "Medication", "Observation", "Procedure"):
        row = session.run(
            f"MATCH (n:Memory:Healthcare:{label}) RETURN count(n) AS c"
        ).single()
        counts[label] = int(row["c"]) if row else 0
    checks["node_counts"] = counts

    # Entity counts.
    entity_counts = {}
    for label in ("Patient", "Provider", "Diagnosis", "Medication", "Procedure"):
        row = session.run(
            f"MATCH (n:Entity:{label}) RETURN count(n) AS c"
        ).single()
        entity_counts[label] = int(row["c"]) if row else 0
    checks["entity_counts"] = entity_counts

    # Random patient coverage — sample 5 patients, confirm each has >=1 relationship.
    sampled_coverage = []
    patients = session.run(
        "MATCH (p:Entity:Patient) RETURN p.name AS pid LIMIT 200"
    ).data()
    for entry in random.sample(patients, min(5, len(patients))):
        pid = entry["pid"]
        rels = session.run(
            "MATCH (:Entity:Patient {name: $pid})-[r]-() RETURN count(r) AS c",
            pid=pid,
        ).single()
        sampled_coverage.append({"patient": pid, "relationships": int(rels["c"]) if rels else 0})
    checks["sampled_patient_coverage"] = sampled_coverage

    # Vector index population sanity.
    vec_row = session.run(
        """
        MATCH (n:Memory:Healthcare)
        WHERE n.embedding IS NOT NULL
        RETURN count(n) AS c, size(head(collect(n.embedding))) AS dim
        """
    ).single()
    checks["embedded_nodes"] = int(vec_row["c"]) if vec_row else 0
    checks["embedding_dim_seen"] = int(vec_row["dim"]) if vec_row and vec_row["dim"] else None

# Write results.
CONFIG.results_path.parent.mkdir(parents=True, exist_ok=True)
CONFIG.results_path.write_text(json.dumps(checks, indent=2, default=str))

print(json.dumps(checks, indent=2, default=str))
print(f"\nResults written to {CONFIG.results_path}")

# %% [markdown]
# ## Next steps
#
# Once the ingest cell reports `patients_done == CONFIG.max_patients`
# and post-ingest checks look healthy, the tier is complete. What
# happens next:
#
# 1. **Keep Neo4j running.** Evaluation runs (Experiments 1 and 2)
#    connect to the same Neo4j instance. You can run eval from this
#    notebook if you want GPU-backed query-embedding, but CPU-side
#    eval works fine too — the queries are cheap and the QA tasks
#    are small.
#
# 2. **Move to the next tier.** Change `TIER` in the config cell
#    (section 4) to `mid` or `scale`, then re-run from section 4
#    onward. Sections 1–3 (runtime, Drive, Tailscale) don't need to
#    rerun unless the Colab session died.
#
# 3. **Tear down.** When all tiers are done:
#    - Download the final checkpoints and results JSONs from Drive.
#    - `neo4j-admin database dump` on the host for an archive.
#    - If using a rented VM, stop or delete it.
#    - Revoke the Tailscale ephemeral authkey so Colab loses tailnet
#      access.
#
# Where findings live:
#
# - Per-tier sanity JSON: `CONFIG.results_path` (on Drive).
# - Experiment 1 (temporal decay) results: produced by the separate
#   eval runner, not this notebook.
# - Experiment 2 (multi-hop reasoning) results: ditto.
# - Final scale-sensitivity curve: `docs/research/scale-validity-findings.md`
#   referenced in Plan B.
